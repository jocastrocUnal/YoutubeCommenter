# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

os.chdir("/content/drive/MyDrive/Colab Notebooks/proyecto youtube nicolas")
os.getcwd()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-73713455d46e> in <module>
#       1 import os
#       2
# ----> 3 os.chdir("/content/drive/MyDrive/Colab Notebooks/proyecto youtube nicolas")
#       4 os.getcwd()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Colab Notebooks/proyecto youtube nicolas'

# %%
import sys
import pandas as pd

sys.path.insert(0, '/content/drive/MyDrive/Colab Notebooks/proyecto youtube nicolas ')

# %%
apiKey = 'AIzaSyCyHlJIuaMUyJwDkFO_etG11XQxrLP2ciA'
playlistId='PLKC7MUki7CBbyMMSlTjMr_KgJ1aiPW8k8'

# %%
from dataApiYouTube import dataPlayList

urldf = dataPlayList(api_Key=apiKey,playlist_Id=playlistId,df=True)
URL_list = urldf["URL"].tolist()

videoID = []
for url in URL_list:
  video_id=url[-11:]
  videoID.append(video_id)

urldf
# Out:
#        Views    Likes  Favorite  Coments Duration Dimension Definition  \
# 0    2387723    31838         0      742     PT5S        2d         hd
# 1   17995592  1462526         0    10421    PT16S        2d         hd
# 2    9605757   102461         0     1926     PT9S        2d         sd
# 3    1323096    11798         0      163     PT8S        2d         sd
# 4    1759606    39655         0      531     PT6S        2d         hd
# 5    2167125    22206         0      436    PT10S        2d         hd
# 6    2150029    56363         0     1369    PT19S        2d         hd
# 7    2983773    32640         0      475     PT9S        2d         hd
# 8    5383772    51862         0      695    PT17S        2d         hd
# 9    4075839    57626         0      649    PT20S        2d         hd
# 10   3382498    24873         0      142    PT11S        2d         sd
# 11   4892496    94760         0     1423     PT8S        2d         hd
# ...

# %%
from dataApiYouTube import dataComments
video_comentario=[]
numvideos = []
n=0
for video in videoID:
  commentdf = dataComments(api_Key=apiKey,video_Id=video,df=True)
  commentdf.sort_values(by="Likes")
  likes = commentdf["Likes"].tolist()
  comment_list = commentdf["CommentOriginal"].tolist()
  num_comment=len(comment_list)
  numvideos.append(num_comment)
  
  for i in range(0,num_comment):
    vidcom = URL_list[n], likes[i], comment_list[i]
    video_comentario.append(vidcom)
  n+=1

# %%
import pandas as pd

print(comment_list)
print(len(numvideos))
video_comentario
coment_video = pd.DataFrame(video_comentario,columns=["videoID","likes","Comment"]) 
coment_video.sort_values(by=["videoID","likes"],ascending=False)
coment_video.to_csv('comentariolikelink1.csv',mode='a')
# Out:
# ['hammie boye', 'Help me, I cannot stop watching', 'So cutee', 'hammie boye', 'Хомяк 🐹', 'this was made 5 years ago yet people in 2022 would love this', 'To whoever wonders,\nThis song is called..\nAlice Deejay Better Off Alone', 'Pov you feel the rainbow', 'he swings the carton and the party’s startin', 'Wake up U NEED the money', 'This what hamsters were born for.', 'I am glad that i was born to see this', 'one braincell in a brain be like', 'Hamna why u do dis to me', 'The slow start is hilarious', 'I hope this is the last thing I see before I die in my wife’s arms', 'i love  it', 'Hampter rave', 'Bro this is what’s gonna be at history classes in the future', 'Name music pls', 'I reply miss 2015', 'Come on, get it together', "old hammie boye\r\n【C】【H】【E】【C】【K】【:】\r\n\r\nATK: low quality bottle of water\r\nDMG: 1-2\r\nHP: 45\n\n\r\n\r\nYou\r\n【C】【H】【E】【C】【K】【:】\r\nATK: heal\r\nDMG: negative 25 (it's a heal)\r\nHP: 45.50", "It's always good to see animals on board with recycling <3"
# ...
