# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
os.chdir("/content/drive/MyDrive/Colab Notebooks/proyecto youtube nicolas ")
os.getcwd()
# Out:
# '/content/drive/MyDrive/Colab Notebooks/proyecto youtube nicolas '

# %%
import sys
import pandas as pd

sys.path.insert(0, '/content/drive/MyDrive/Colab Notebooks/proyecto youtube nicolas ')

# %%
#/content/drive/MyDrive/Colab Notebooks/proyecto youtube nicolas 
comurl = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/proyecto youtube nicolas /comentariolikelink1.csv",lineterminator='\n')
comurl = comurl.drop('Unnamed: 0',axis=1) 
comurl = comurl.applymap(str) 
comurl
# Out:
#                             videoID likes  \
# 0      https://youtu.be/Ac4Bga-WtHQ     0
# 1      https://youtu.be/Ac4Bga-WtHQ     0
# 2      https://youtu.be/Ac4Bga-WtHQ     0
# 3      https://youtu.be/Ac4Bga-WtHQ     0
# 4      https://youtu.be/Ac4Bga-WtHQ     0
# ...                             ...   ...
# 18500  https://youtu.be/l1heD4T8Yco    37
# 18501  https://youtu.be/l1heD4T8Yco     0
# 18502  https://youtu.be/l1heD4T8Yco  4869
# 18503  https://youtu.be/l1heD4T8Yco  2416
# 18504  https://youtu.be/l1heD4T8Yco     0
#
#                                                  Comment
# 0                      Maui: winks\n\n2.3M people: *YES*
# 1      The thumbnail says: "THIS IS A MEME NOW" in Co...
# 2                                                     ;)
# 3                                                    lol
# 4                                                  👁️👄👁️
# ...                                                  ...
# ...

# %%
coment = comurl['Comment'].to_list()
videoid = comurl['videoID'].to_list()
likes = comurl['likes'].to_list()

# %%
numcomen=len(comurl)
finallist = []
for i in range(0,numcomen):
  if i%100==0:
    print("x", end = (''))
  if len(coment[i].split()) > 4 :
    newdf = videoid[i], likes[i], coment[i]
    finallist.append(newdf)
# Out:
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %%
finallist1=pd.DataFrame(finallist,columns=['VideoID','Likes','Comentario'])

finallist1.to_csv('datosmulti.csv',mode = 'a')
finallist1
# Out:
#                             VideoID Likes  \
# 0      https://youtu.be/Ac4Bga-WtHQ     0
# 1      https://youtu.be/Ac4Bga-WtHQ     0
# 2      https://youtu.be/Ac4Bga-WtHQ     0
# 3      https://youtu.be/Ac4Bga-WtHQ     0
# 4      https://youtu.be/Ac4Bga-WtHQ     0
# ...                             ...   ...
# 10631  https://youtu.be/l1heD4T8Yco     0
# 10632  https://youtu.be/l1heD4T8Yco  2440
# 10633  https://youtu.be/l1heD4T8Yco    37
# 10634  https://youtu.be/l1heD4T8Yco     0
# 10635  https://youtu.be/l1heD4T8Yco  2416
#
#                                               Comentario
# 0                      Maui: winks\n\n2.3M people: *YES*
# 1      The thumbnail says: "THIS IS A MEME NOW" in Co...
# 2      Praise the Lord Halleluiah! Jesus loves you!!!...
# 3      The subtly larger mouth in the second click is...
# 4      this isnt funny but its random so thats why it...
# ...                                                  ...
# ...

# %%
coment1 = finallist1['Comentario'].to_list()
videoid1 = finallist1['VideoID'].to_list()
likes1 = finallist1['Likes'].to_list()

# %%
numcomen=len(finallist)
finallist2 = []
for i in range(0,numcomen):
  if i%100==0:
    print("x", end = (''))
  palabra = coment1[i].split()
  for j in reversed(range(0,len(palabra))):
    if len(palabra[j]) <= 3:
      palabra.pop(j)
  newcoment = ' '.join(palabra)
  if len(newcoment)!=0:
    newdf1 = videoid1[i], likes1[i], newcoment
    finallist2.append(newdf1)
# Out:
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %%
finallist2=pd.DataFrame(finallist2,columns=['VideoID','Likes','Comentario'])
finallist2.to_csv('datosmulti2.csv',mode = 'a')

# %%
coment = finallist2['Comentario'].to_list()
videoid = finallist2['VideoID'].to_list()
likes = finallist2['Likes'].to_list()

# %%
numcomen=len(finallist2)
finallist = []
for i in range(0,numcomen):
  if i%100==0:
    print("x", end = (''))
  if len(coment[i].split()) > 4 :
    newdf = videoid[i], likes[i], coment[i]
    finallist.append(newdf)
# Out:
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx

# %%
finallist=pd.DataFrame(finallist,columns=['VideoID','Likes','Comentario'])
finallist['Comentario']=(finallist['Comentario']
           .str.replace("[<>:]"," "))
finallist.to_csv('datosmulti5.csv',mode = 'a')
finallist
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   This is separate from the ipykernel package so we can avoid doing imports until
#                            VideoID Likes  \
# 0     https://youtu.be/Ac4Bga-WtHQ     0
# 1     https://youtu.be/Ac4Bga-WtHQ     0
# 2     https://youtu.be/Ac4Bga-WtHQ     0
# 3     https://youtu.be/Ac4Bga-WtHQ     0
# 4     https://youtu.be/Ac4Bga-WtHQ     0
# ...                            ...   ...
# 5849  https://youtu.be/l1heD4T8Yco  1217
# 5850  https://youtu.be/l1heD4T8Yco     0
# 5851  https://youtu.be/l1heD4T8Yco  2440
# 5852  https://youtu.be/l1heD4T8Yco    37
# 5853  https://youtu.be/l1heD4T8Yco     0
#
#                                              Comentario
# 0                        Maui  winks 2.3M people  *YES*
# 1            thumbnail says  "THIS MEME NOW" Comic Sans
# 2            Praise Lord Halleluiah! Jesus loves you!!!
# ...
